# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# BY **JUDITH OKON**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it offers opportunities for problem-solving and innovation, as well as a high demand for skilled professionals in the job market.*

# %% [markdown]
# ### The code below is supposed to print the result of the summantion of 3 values

# %%
summation = 3 + 4 + 5
print(summation)
# Out:
# 12

# %% [markdown]
# 1. Thank you for reading my noteook
# 2. The link to this class can be found [Here](https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook)
# 3. > This is a blocked quote

# %% [markdown]
# ___
